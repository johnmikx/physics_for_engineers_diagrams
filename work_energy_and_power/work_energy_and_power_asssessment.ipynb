# %% [markdown]
# A child pulls a 5.6 kg box with a distance of 12 m along a horizontal surface at a constant speed. What work does the child do on the box if the coefficient of kinetic friction is 0.20 and the cord makes an angle of 45° with the horizontal?

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the figure with a dark background
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(10, 4))

# Ground
ax.plot([-1, 6], [0, 0], 'w-', lw=2, label='Ground')

# Box
box = plt.Rectangle((0, 0), 1, 0.5, fc='gray', ec='white', label='Box (5.6 kg)')
ax.add_patch(box)

# Forces
# Tension at 45 degrees
ax.arrow(0.5, 0.25, 0.7, 0.7, head_width=0.1, head_length=0.1, fc='red', ec='red')
ax.text(1.3, 1, 'T = 12.9 N', color='red', fontsize=12)

# Normal force
ax.arrow(0.5, 0.5, 0, 0.5, head_width=0.1, head_length=0.1, fc='green', ec='green')
ax.text(0.8, 1.1, 'N = 45.7 N', color='green', fontsize=12, ha='center')

# Weight
ax.arrow(0.5, 0.5, 0, -0.5, head_width=0.1, head_length=0.1, fc='cyan', ec='cyan')
ax.text(0.5, -0.3, '54.9 N', color='cyan', fontsize=12, ha='center')

# Friction
ax.arrow(0.5, 0.25, -0.5, 0, head_width=0.1, head_length=0.1, fc='yellow', ec='yellow')
ax.text(-0.1, 0.25, 'f_k = 9.1 N', color='yellow', fontsize=12, ha='right')

# Motion direction
ax.arrow(2, 0.25, 1, 0, head_width=0.1, head_length=0.1, fc='white', ec='white')
ax.text(3, 0.35, '12 m', color='white', fontsize=12, ha='center')

# Styling
ax.set_xlim(-1, 6)
ax.set_ylim(-1, 2)
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('Horizontal Surface', fontsize=14, color='white')
ax.set_title('Box Pulled at Constant Speed', fontsize=16, color='white')
ax.legend(fontsize=12, loc='upper left')
ax.grid(True, ls='--', alpha=0.3)

# Remove spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

plt.show()

# %% [markdown]
# To push a 25 kg crate up a 27° incline, a worker exerts a force of 120 N, parallel to the incline. As the crate slides 3.6 m, how much work is done on the crate by: (a) the worker, (b) the force of gravity, and (c) the normal force due to the incline?

# %%
# Set up the figure with a dark background
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(10, 6))

# Incline
theta = np.deg2rad(27)
length = 4  # Scaled for plot
x = [0, length * np.cos(theta)]
y = [0, length * np.sin(theta)]
ax.plot(x, y, 'w-', lw=4, label='Incline (27°)')

# Ground
ax.plot([-1, 4], [0, 0], 'w-', lw=2, label='Ground')

# Crate
crate_size = 0.5
crate_x = (length - crate_size) * np.cos(theta)
crate_y = (length - crate_size) * np.sin(theta)
crate = plt.Rectangle((crate_x - crate_size/2, crate_y), crate_size, crate_size/2,
                     angle=27, fc='gray', ec='white', label='Crate (25 kg)')
ax.add_patch(crate)

# Forces
# Worker’s force
ax.arrow(crate_x, crate_y + crate_size/4, 0.7 * np.cos(theta), 0.7 * np.sin(theta),
         head_width=0.1, head_length=0.1, fc='red', ec='red')
ax.text(crate_x + 0.8 * np.cos(theta), crate_y + 0.8 * np.sin(theta) + 0.1,
        'F = 120 N', color='red', fontsize=12)

# Normal force
ax.arrow(crate_x, crate_y + crate_size/4, -0.5 * np.sin(theta), 0.5 * np.cos(theta),
         head_width=0.1, head_length=0.1, fc='green', ec='green')
ax.text(crate_x - 0.6 * np.sin(theta), crate_y + 0.6 * np.cos(theta) + 0.1,
        'N = 218 N', color='green', fontsize=12)

# Gravity
ax.arrow(crate_x, crate_y + crate_size/4, 0, -0.7, head_width=0.1, head_length=0.1,
         fc='cyan', ec='cyan')
ax.text(crate_x, crate_y - 0.8, 'mg = 245 N', color='cyan', fontsize=12, ha='center')

# Displacement
ax.arrow(crate_x - 0.5 * np.cos(theta), crate_y - 0.5 * np.sin(theta),
         0.5 * np.cos(theta), 0.5 * np.sin(theta),
         head_width=0.1, head_length=0.1, fc='white', ec='white')
ax.text(crate_x, crate_y + 0.1, '3.6 m', color='white', fontsize=12, ha='center')

# Styling
ax.set_xlim(-1, 4)
ax.set_ylim(-1, 2.5)
ax.set_aspect('equal')
ax.set_xlabel('x (m)', fontsize=14, color='white')
ax.set_ylabel('y (m)', fontsize=14, color='white')
ax.set_title('Crate on Incline', fontsize=16, color='white')
ax.legend(fontsize=12, loc='upper left')
ax.grid(True, ls='--', alpha=0.3)

# Remove spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('white')
ax.spines['bottom'].set_color('white')

plt.show()

# %% [markdown]
# A body of mass m starts down from the top of an inclined plane 20 ft long and 10 ft high. What is its velocity at a point 12 ft from the top if coefficient of friction is 0.1?

# %%
# Set up the figure with a dark background
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(10, 6))

# Incline
theta = np.deg2rad(30)
length = 4  # Scaled for plot
x = [0, length * np.cos(theta)]
y = [0, length * np.sin(theta)]
ax.plot(x, y, 'w-', lw=4, label='Incline (30°)')

# Ground
ax.plot([-1, 4], [0, 0], 'w-', lw=2, label='Ground')

# Body at 12 ft (scaled: 12/20 * length)
pos = 0.6 * length
body_x = pos * np.cos(theta)
body_y = pos * np.sin(theta)
body = plt.Circle((body_x, body_y), 0.15, fc='gray', ec='white', label='Body')
ax.add_patch(body)

# Forces
# Gravity
ax.arrow(body_x, body_y, 0, -0.7, head_width=0.1, head_length=0.1, fc='cyan', ec='cyan')
ax.text(body_x, body_y - 0.9, 'mg', color='cyan', fontsize=12, ha='center')

# Normal force
ax.arrow(body_x, body_y, 0.5 * np.sin(theta), -0.5 * np.cos(theta),
         head_width=0.1, head_length=0.1, fc='green', ec='green')
ax.text(body_x + 0.6 * np.sin(theta), body_y - 0.6 * np.cos(theta),
        'N', color='green', fontsize=12)

# Friction
ax.arrow(body_x, body_y, -0.3 * np.cos(theta), -0.3 * np.sin(theta),
         head_width=0.1, head_length=0.1, fc='yellow', ec='yellow')
ax.text(body_x - 0.4 * np.cos(theta), body_y - 0.4 * np.sin(theta),
        'f_k', color='yellow', fontsize=12)

# Velocity
ax.arrow(body_x, body_y, 0.5 * np.cos(theta), 0.5 * np.sin(theta),
         head_width=0.1, head_length=0.1, fc='red', ec='red')
ax.text(body_x + 0.6 * np.cos(theta), body_y + 0.6 * np.sin(theta),
        'v = 17.82 ft/s', color='red', fontsize=12)

# Label position
ax.text(body_x, body_y + 0.2, '12 ft', color='white', fontsize=12, ha='center')

# Styling
ax.set_xlim(-1, 4)
ax.set_ylim(-1, 2.5)
ax.set_aspect('equal')
ax.set_xlabel('x (ft)', fontsize=14, color='white')
ax.set_ylabel('y (ft)', fontsize=14, color='white')
ax.set_title('Body Sliding Down Incline', fontsize=16, color='white')
ax.legend(fontsize=12, loc='upper left')
ax.grid(True, ls='--', alpha=0.3)

# Remove spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('white')
ax.spines['bottom'].set_color('white')

plt.show()

# %% [markdown]
# Two snow-covered peaks are at elevations of 862 m and 741 m above the valley between them. If a skier starts from rest on the higher peak and just coasted down without exerting any effort, at what speed would he arrive at the lower peak?

# %%
# Set up the figure with a dark background
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 6))

# Terrain (simplified parabolic valley)
x = np.linspace(-2, 2, 100)
y_valley = 0.5 * x**2  # Valley curve
y_high_peak = np.full(10, 0.862)  # Higher peak at 862 m (scaled)
y_low_peak = np.full(10, 0.741)   # Lower peak at 741 m (scaled)
x_left = np.linspace(-3, -2, 10)
x_right = np.linspace(2, 3, 10)

# Plot terrain
ax.plot(x, y_valley, 'w-', lw=3, label='Valley')
ax.plot(x_left, y_high_peak, 'w-', lw=3)
ax.plot(x_right, y_low_peak, 'w-', lw=3)

# Skier
skier_high = plt.Circle((-2, 0.862), 0.05, fc='cyan', ec='white', label='Skier (Start)')
skier_low = plt.Circle((2, 0.741), 0.05, fc='red', ec='white', label='Skier (End)')
ax.add_patch(skier_high)
ax.add_patch(skier_low)

# Annotations
ax.text(-2, 0.9, 'Higher Peak\n862 m', color='white', fontsize=12, ha='center')
ax.text(2, 0.79, 'Lower Peak\n741 m', color='white', fontsize=12, ha='center')
ax.text(0, 0.1, 'Valley', color='white', fontsize=12, ha='center')
ax.text(2.3, 0.741, 'v = 48.7 m/s', color='red', fontsize=12)

# Velocity arrow
ax.arrow(2, 0.741, 0.3, 0, head_width=0.02, head_length=0.05, fc='red', ec='red')

# Energy note
ax.text(0, 1.0, 'KE_initial + PE_initial = KE_final + PE_final',
        color='white', fontsize=12, ha='center', bbox=dict(facecolor='black', alpha=0.5))

# Styling
ax.set_xlim(-3.5, 3.5)
ax.set_ylim(-0.1, 1.1)
ax.set_aspect('equal')
ax.set_xlabel('Horizontal Distance (arbitrary)', fontsize=14, color='white')
ax.set_ylabel('Height (km)', fontsize=14, color='white')
ax.set_title('Skier Coasting Between Peaks', fontsize=16, color='white')
ax.legend(fontsize=12, loc='upper left')
ax.grid(True, ls='--', alpha=0.3)

# Remove spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('white')
ax.spines['bottom'].set_color('white')

plt.show()

# %% [markdown]
# An elevator with a 10-person capacity (each person with an average mass of 68 kg) raises passengers to a height of 152 m in 55.0 s at constant speed. Find the power output of the motor assuming no frictional losses?

# %%
# Set up the figure with a dark background
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(8, 10))

# Building (simplified)
ax.plot([0, 0], [0, 3], 'w-', lw=3, label='Building')
ax.plot([1, 1], [0, 3], 'w-', lw=3)

# Elevator
elevator = plt.Rectangle((0.2, 0.2), 0.6, 0.4, fc='gray', ec='white', label='Elevator (680 kg)')
ax.add_patch(elevator)

# Cable
ax.plot([0.5, 0.5], [0.6, 3], 'w--', lw=2)

# Forces
# Motor force (tension)
ax.arrow(0.5, 0.6, 0, 0.5, head_width=0.05, head_length=0.1, fc='red', ec='red')
ax.text(0.5, 1.2, 'F = 6664 N', color='red', fontsize=12, ha='center')

# Weight
ax.arrow(0.5, 0.4, 0, -0.3, head_width=0.05, head_length=0.1, fc='cyan', ec='cyan')
ax.text(0.5, 0, 'mg = 6664 N', color='cyan', fontsize=12, ha='center')

# Motion
ax.arrow(0.7, 0.4, 0, 0.7, head_width=0.05, head_length=0.1, fc='white', ec='white')
ax.text(0.9, 0.7, '152 m\n55 s', color='white', fontsize=12)

# Power note
ax.text(0.5, 2.5, 'Power = 18.42 kW', color='white', fontsize=12, ha='center',
        bbox=dict(facecolor='black', alpha=0.5))

# Styling
ax.set_xlim(-0.5, 1.5)
ax.set_ylim(-0.5, 3.5)
ax.set_aspect('equal')
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('Horizontal', fontsize=14, color='white')
ax.set_ylabel('Height', fontsize=14, color='white')
ax.set_title('Elevator Power Output', fontsize=16, color='white')
ax.legend(fontsize=12, loc='upper left')
ax.grid(True, ls='--', alpha=0.3)

# Remove spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('white')
ax.spines['bottom'].set_color('white')

plt.show()

# %% [markdown]
# A cord is used to lower vertically a block of mass *M* a distance *d* at a constant downward acceleration of g/4. (a) Find the work done by the cord on the block. (b) Find the work done by the work of gravity.

# %%
# Set up the figure with a dark background
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(6, 10))

# Cord
ax.plot([0.5, 0.5], [0, 3], 'w--', lw=2, label='Cord')

# Block
block = plt.Rectangle((0.3, 0.2), 0.4, 0.4, fc='gray', ec='white', label='Block (M)')
ax.add_patch(block)

# Forces
# Tension (upward)
ax.arrow(0.5, 0.6, 0, 0.5, head_width=0.05, head_length=0.1, fc='red', ec='red')
ax.text(0.5, 1.2, 'T = 3Mg/4', color='red', fontsize=12, ha='center')

# Gravity (downward)
ax.arrow(0.5, 0.4, 0, -0.5, head_width=0.05, head_length=0.1, fc='cyan', ec='cyan')
ax.text(0.5, -0.1, 'mg', color='cyan', fontsize=12, ha='center')

# Displacement
ax.arrow(0.7, 0.6, 0, -0.7, head_width=0.05, head_length=0.1, fc='white', ec='white')
ax.text(0.9, 0.3, 'd', color='white', fontsize=12)

# Work notes
ax.text(0.5, 2.5, 'W_cord = -3Mgd/4\nW_gravity = Mgd',
        color='white', fontsize=12, ha='center',
        bbox=dict(facecolor='black', alpha=0.5))

# Styling
ax.set_xlim(0, 1)
ax.set_ylim(-0.5, 3.5)
ax.set_aspect('equal')
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('Horizontal', fontsize=14, color='white')
ax.set_ylabel('Vertical', fontsize=14, color='white')
ax.set_title('Block Lowered by Cord', fontsize=16, color='white')
ax.legend(fontsize=12, loc='upper left')
ax.grid(True, ls='--', alpha=0.3)

# Remove spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

plt.show()

# %% [markdown]
# A projectile with a mass of 2.4 kg is fired from a cliff 125 m high with an initial velocity of 150 m/s, directed 41.0° above the horizontal. What are (a) the kinetic energy of the projectile just after firing and (b) its potential energy? (c) Use conservation of energy to find the speed of the projectile just before it strikes the ground.

# %%
# Set up the figure with a dark background
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 8))

# Ground
ax.plot([-2, 10], [0, 0], 'w-', lw=2, label='Ground')

# Cliff
ax.plot([-2, 0], [1.25, 1.25], 'w-', lw=3, label='Cliff (125 m)')

# Projectile trajectory (approximate parabola)
t = np.linspace(0, 3, 100)
vx = 150 * np.cos(np.deg2rad(41))
vy = 150 * np.sin(np.deg2rad(41))
x = vx * t
y = 1.25 + vy * t - 0.5 * 9.8 * t**2
ax.plot(x, y, 'cyan', lw=2, label='Trajectory')

# Projectile at start
ax.plot(0, 1.25, 'o', ms=10, c='cyan', label='Projectile (2.4 kg)')

# Initial velocity
ax.arrow(0, 1.25, 0.5 * np.cos(np.deg2rad(41)), 0.5 * np.sin(np.deg2rad(41)),
         head_width=0.05, head_length=0.1, fc='cyan', ec='cyan')
ax.text(0.6, 1.4, '150 m/s, 41°', color='cyan', fontsize=12)

# Final position (approximate)
ax.plot(x[-1], 0, 'o', ms=10, c='red')
ax.arrow(x[-1], 0, 0.5, -0.3, head_width=0.05, head_length=0.1, fc='red', ec='red')
ax.text(x[-1] + 0.6, 0.1, 'v = 158 m/s', color='red', fontsize=12)

# Energy notes
ax.text(5, 2, 'KE₀ = 27,000 J\nPE₀ = 2940 J',
        color='white', fontsize=12, ha='center',
        bbox=dict(facecolor='black', alpha=0.5))

# Styling
ax.set_xlim(-2, 10)
ax.set_ylim(-0.5, 2.5)
ax.set_aspect('equal')
ax.set_xlabel('x (m)', fontsize=14, color='white')
ax.set_ylabel('y (m, scaled)', fontsize=14, color='white')
ax.set_title('Projectile Motion from Cliff', fontsize=16, color='white')

# Move legend to a less intrusive spot
ax.legend(fontsize=12, loc='center right', framealpha=0.7)

ax.grid(True, ls='--', alpha=0.3)

# Remove spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('white')
ax.spines['bottom'].set_color('white')

plt.show()

# %% [markdown]
# A 220-lb man jumps out a window into a fire net 36 ft below. The net stretches 4.4 ft before bringing him to rest and tossing him back into the air. What is the potential energy of the stretched net if no energy is dissipated?

# %%
# Set up the figure with a dark background
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(8, 10))

# Ground
ax.plot([-2, 2], [0, 0], 'w-', lw=2, label='Ground')

# Unstretched net
ax.plot([-1, 1], [0.5, 0.5], 'w--', lw=2, label='Unstretched Net')

# Stretched net (approximate curve)
x_net = np.linspace(-1, 1, 100)
y_net = 0.5 - 0.2 * np.sin(np.pi * (x_net + 1) / 2)
ax.plot(x_net, y_net, 'yellow', lw=2, label='Stretched Net')

# Man at window
ax.plot(0, 4.1, 'o', ms=10, c='cyan', label='Man (220 lb)')

# Man at lowest point
ax.plot(0, 0.06, 'o', ms=10, c='red')

# Window
ax.plot([-1, 1], [4.1, 4.1], 'w-', lw=3, label='Window (36 ft)')

# Displacement
ax.arrow(0.2, 4.1, 0, -3.64, head_width=0.05, head_length=0.1, fc='white', ec='white')
ax.text(0.3, 2.5, '40.4 ft', color='white', fontsize=12)

# Energy note
ax.text(0, 2, 'PE_net = 8888 ft·lb', color='white', fontsize=12, ha='center',
        bbox=dict(facecolor='black', alpha=0.5))

# Styling
ax.set_xlim(-2, 2)
ax.set_ylim(-0.5, 4.5)
ax.set_aspect('equal')
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('Horizontal', fontsize=14, color='white')
ax.set_ylabel('Vertical (scaled)', fontsize=14, color='white')
ax.set_title('Man Jumping into Fire Net', fontsize=16, color='white')
ax.legend(fontsize=12, loc='upper left')
ax.grid(True, ls='--', alpha=0.3)

# Remove spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

plt.show()

# %% [markdown]
# Starting a race, a 68.2-kg sprinter runs the first 7.04 m in 1.60 s, starting from rest and accelerating uniformly. What average power does the sprinter generate during the 1.60-s interval?

# %%
# Set up the figure with a dark background
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 6))

# Track
ax.plot([-1, 8], [0, 0], 'w-', lw=3, label='Track')

# Sprinter at start
ax.plot(0, 0.2, 'o', ms=15, c='cyan', label='Sprinter (68.2 kg)')

# Sprinter at end
ax.plot(7.04, 0.2, 'o', ms=15, c='red')

# Motion
ax.arrow(0, 0.2, 7.04, 0, head_width=0.1, head_length=0.2, fc='white', ec='white')
ax.text(3.5, 0.4, '7.04 m, 1.60 s\nv = 8.8 m/s', color='white', fontsize=12, ha='center')

# Force (acceleration)
ax.arrow(7.04, 0.2, 0.5, 0, head_width=0.1, head_length=0.2, fc='cyan', ec='cyan')
ax.text(7.54, 0.3, 'a = 5.5 m/s²', color='cyan', fontsize=12)

# Power note
ax.text(3.5, 1, 'P_avg = 1651 W', color='white', fontsize=12, ha='center',
        bbox=dict(facecolor='black', alpha=0.5))

# Styling
ax.set_xlim(-1, 8)
ax.set_ylim(-0.5, 1.5)
ax.set_aspect('equal')
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('Distance (m)', fontsize=14, color='white')
ax.set_ylabel('Height', fontsize=14, color='white')
ax.set_title('Sprinter Accelerating', fontsize=16, color='white')
ax.legend(fontsize=12, loc='upper left')
ax.grid(True, ls='--', alpha=0.3)

# Remove spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('white')

plt.show()

# %% [markdown]
# A horse pulls a cart with a force of 42.0 lbs at an angle of 27° with the horizontal and moves along at a speed of 6.20 mi/hr. (a) How much work does the horse do in 12 min? (b) Find the power output of the horse in hp.

# %%
# Set up the figure with a dark background
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 6))

# Ground
ax.plot([-2, 8], [0, 0], 'w-', lw=3, label='Ground')

# Cart
cart = plt.Rectangle((2, 0), 2, 1, fc='gray', ec='white', label='Cart')
ax.add_patch(cart)

# Horse (simplified as a point)
ax.plot(1, 0.5, 'o', ms=15, c='cyan', label='Horse')

# Force vector
theta = np.deg2rad(27)
ax.arrow(1, 0.5, 0.5 * np.cos(theta), 0.5 * np.sin(theta),
         head_width=0.1, head_length=0.2, fc='cyan', ec='cyan')
ax.text(1.6, 0.8, 'F = 42 lb, 27°', color='cyan', fontsize=12)

# Motion
ax.arrow(2, 1.2, 2, 0, head_width=0.1, head_length=0.2, fc='white', ec='white')
ax.text(3, 1.4, 'v = 6.20 mi/hr\n12 min', color='white', fontsize=12)

# Work and power note
ax.text(5, 2, 'W = 245,000 ft·lb\nP = 0.619 hp',
        color='white', fontsize=12, ha='center',
        bbox=dict(facecolor='black', alpha=0.5))

# Styling
ax.set_xlim(-2, 8)
ax.set_ylim(-0.5, 2.5)
ax.set_aspect('equal')
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('Horizontal', fontsize=14, color='white')
ax.set_ylabel('Vertical', fontsize=14, color='white')
ax.set_title('Horse Pulling Cart', fontsize=16, color='white')
ax.legend(fontsize=12, loc='upper left')
ax.grid(True, ls='--', alpha=0.3)

# Remove spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('white')

plt.show()
